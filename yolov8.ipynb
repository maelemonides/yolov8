# %% [markdown]
# <a href="https://colab.research.google.com/github/maelemonides/yolov8/blob/main/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
from ultralytics import YOLO
from PIL import Image

# Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data='coco128.yaml', epochs=5, imgsz=640)
# Out:
# ...
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# List of image paths in your Google Drive
image_paths = [
    '/content/drive/My Drive/cat1.jpg',
    '/content/drive/My Drive/cat2.jpg',
    '/content/drive/My Drive/cat3.jpg'
]

# Run batched inference on the list of images
results = model(image_paths)  # Returns a list of Results objects

# Process results list
for i, result in enumerate(results):
    # Access detection outputs
    boxes = result.boxes  # Bounding boxes
    masks = result.masks  # Masks (if available)
    probs = result.probs  # Class probabilities

    # Display the result
    result.show()  # Display to the screen

    # Save the result to Google Drive
    result.save(filename=f'/content/drive/My Drive/result_{i}.jpg')  # Save to Google Drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# 0: 640x640 3 sheeps, 274.9ms
# 1: 640x640 1 cat, 1 dog, 274.9ms
# 2: 640x640 1 cat, 1 dog, 274.9ms
# Speed: 11.5ms preprocess, 274.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# List of image paths
result_paths = [
    '/content/drive/My Drive/result_0.jpg',
    '/content/drive/My Drive/result_1.jpg',
    '/content/drive/My Drive/result_2.jpg'  # Corrected index
]

# Plot the result images
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

for i, path in enumerate(result_paths):
    # Load image
    img = mpimg.imread(path)

    # Display image
    axs[i].imshow(img)
    axs[i].axis('off')

# Show the plot
plt.show()

# %%
# Save the trained model to Google Drive
model.save('/content/drive/My Drive/yolov8_trained_model.pt')

# %%
# @title Setup code
# !pip install -q streamlit
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64
import subprocess
subprocess.Popen(["./cloudflared-linux-amd64", "tunnel", "--url", "http://localhost:8501"])
# !nohup /content/cloudflared-linux-amd64 tunnel --url http://localhost:8501 &
# Out:
# --2024-03-20 14:11:14--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2024.3.0/cloudflared-linux-amd64 [following]
# --2024-03-20 14:11:14--  https://github.com/cloudflare/cloudflared/releases/download/2024.3.0/cloudflared-linux-amd64
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !grep -o 'https://.*\.trycloudflare.com' nohup.out | head -n 1 | xargs -I {} echo "Your tunnel url {}"
# Out:
# Your tunnel url https://flood-andrea-offshore-saskatchewan.trycloudflare.com

# %%
# !streamlit run /content/app.py &>/content/logs.txt &

# %%
# %%writefile app.py
import streamlit as st
from PIL import Image
from google.colab import drive
from ultralytics import YOLO

# Load the saved model from Google Drive
model_path = '/content/drive/My Drive/yolov5_trained_model.pt'
model = None

try:
    model = YOLO(model_path)
except Exception as e:
    st.error(f"Error loading the model: {e}")

def main():
    st.title("YOLOv5 Object Detection with Streamlit")

    uploaded_image = st.file_uploader("Choose an image...", type=["jpg", "jpeg", "png"])

    if uploaded_image is not None:
        image = Image.open(uploaded_image)
        st.image(image, caption="Uploaded Image", use_column_width=True)

        if st.button("Run Inference"):
            if model is None:
                st.error("Model not loaded. Please check the model path.")
            else:
                results = model(image)
                st.write("Inference Results:", results)

if __name__ == "__main__":
    main()
# Out:
# Overwriting app.py
